# %%
import pandas as pd

# %%
df = pd.read_csv("..\data\Cleaned_NewsData.csv" )
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\hanni\AppData\Local\Temp\ipykernel_8900\2211293743.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df = pd.read_csv("..\data\Cleaned_NewsData.csv" )

# %%
df.drop('Unnamed: 0',inplace = True,axis = 1)

# %%
df.head()
# Out:
#                                                title  \
# 0  Dürr Aktiengesellschaft (OTCMKTS:DURYY) Tradin...
# 1  FDM Group (OTCMKTS:FDDMF) Trading Down 1.7% – ...
# 2  ‘Third revolution’: CDS Anil Chauhan warns abo...
# 3  Russia's Air Defense Systems Ready to Counter ...
# 4  China Space Station receives new supplies from...
#
#                                                  url  \
# 0  https://www.etfdailynews.com/2025/07/16/durr-a...
# 1  https://www.etfdailynews.com/2025/07/16/fdm-gr...
# 2  https://economictimes.indiatimes.com/news/defe...
# 3  https://www.globalsecurity.org/wmd/library/new...
# 4  https://www.globalsecurity.org/space/library/n...
#
#                                            thumbnail              source  \
# 0  https://www.americanbankingnews.com/wp-content...      ETF Daily News
# 1  https://www.americanbankingnews.com/wp-content...      ETF Daily News
# 2  https://img.etimg.com/thumb/msid-122562287,wid...  The Times of India
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df['domain'] == "Technology"].sort_values('Date_Format')
# Out:
#                                                 title  \
# 0   Dürr Aktiengesellschaft (OTCMKTS:DURYY) Tradin...
# 27  Naftogaz Partners with Baker Hughes to Strengt...
# 28       Qi2 3-in-1 Portable Charging Station for $39
# 29                3 More Campus Leaders Face Congress
# 30       Qi2 3-in-1 Portable Charging Station for $39
# 31       Qi2 3-in-1 Portable Charging Station for $39
# 32       Qi2 3-in-1 Portable Charging Station for $39
# 33       Qi2 3-in-1 Portable Charging Station for $39
# 34  Telecom Italia (OTCMKTS:TIAOF) Trading Up 7.1%...
# 35  S4 Capital (OTCMKTS:SCPPF) Trading 4.2% Higher...
# 36  Brokerages Set Ballard Power Systems, Inc. (NA...
# 37  Analyzing 1-800 FLOWERS.COM (NASDAQ:FLWS) and ...
# 38  Reviewing AECOM (NYSE:ACM) and Alfa Laval (OTC...
# 39  Reviewing MTN Group (OTCMKTS:MTNOY) and Vodafo...
# 40  Analysts Set Microchip Technology Incorporated...
# 41  LyondellBasell Industries N.V. (NYSE:LYB) Rece...
# ...

# %%
cols_to_check = [col for col in df.columns if col not in ('Date_Format',"Time_Format",'url')]
df.drop_duplicates(cols_to_check,inplace=True)

# %%
cols_to_check
# Out:
# ['title', 'url', 'thumbnail', 'source', 'domain', 'sentiment_label']

# %%
df.reset_index(drop = True,inplace = True)

# %%
df
# Out:
#                                                  title  \
# 0    Dürr Aktiengesellschaft (OTCMKTS:DURYY) Tradin...
# 1    FDM Group (OTCMKTS:FDDMF) Trading Down 1.7% – ...
# 2    ‘Third revolution’: CDS Anil Chauhan warns abo...
# 3    Russia's Air Defense Systems Ready to Counter ...
# 4    China Space Station receives new supplies from...
# ..                                                 ...
# 931  Texas flood survivors look for God in the face...
# 932  Vanishing data in the U.S. undermines good pub...
# 933  From ‘No Nukes’ to Nuclear Now: The progressiv...
# 934  From ‘No Nukes’ to Nuclear Now: The progressiv...
# 935  A warning from the future: The risk if NZ gets...
#
#                                                    url  \
# 0    https://www.etfdailynews.com/2025/07/16/durr-a...
# 1    https://www.etfdailynews.com/2025/07/16/fdm-gr...
# 2    https://economictimes.indiatimes.com/news/defe...
# 3    https://www.globalsecurity.org/wmd/library/new...
# ...

# %%
df[df['domain'] == "Technology"].sort_values('Date_Format')
# Out:
#                                                 title  \
# 0   Dürr Aktiengesellschaft (OTCMKTS:DURYY) Tradin...
# 24  Barclays Forecasts Strong Price Appreciation f...
# 25  SoFi Technologies (NASDAQ:SOFI) Lowered to “Ma...
# 26  Naftogaz Partners with Baker Hughes to Strengt...
# 27       Qi2 3-in-1 Portable Charging Station for $39
# 28                3 More Campus Leaders Face Congress
# 29  Telecom Italia (OTCMKTS:TIAOF) Trading Up 7.1%...
# 30  S4 Capital (OTCMKTS:SCPPF) Trading 4.2% Higher...
# 31  Brokerages Set Ballard Power Systems, Inc. (NA...
# 32  Analyzing 1-800 FLOWERS.COM (NASDAQ:FLWS) and ...
# 33  Reviewing AECOM (NYSE:ACM) and Alfa Laval (OTC...
# 34  Reviewing MTN Group (OTCMKTS:MTNOY) and Vodafo...
# 35  Analysts Set Microchip Technology Incorporated...
# 36  LyondellBasell Industries N.V. (NYSE:LYB) Rece...
# 37  Etsy, Inc. (NASDAQ:ETSY) Receives $49.91 Conse...
# 38  Glaukos Corporation (NYSE:GKOS) Receives $134....
# ...

# %%
df.to_csv('..\data\Cleaned_NewsData.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\hanni\AppData\Local\Temp\ipykernel_8900\2444622077.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df.to_csv('..\data\Cleaned_NewsData.csv')

# %%
# Out:
# Empty DataFrame
# Columns: [title, url, thumbnail, source, domain, sentiment_label, Date_Format, Time_Format]
# Index: []
